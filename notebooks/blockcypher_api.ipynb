# %%
import requests

# %%
res = requests.get("https://api.blockcypher.com/v1/btc/main/addrs/bc1qvzn8l5rm70et6kc5r9xsxn9xwj80ycc4clgukg/full").json()
res
# Out:
# {'address': 'bc1qvzn8l5rm70et6kc5r9xsxn9xwj80ycc4clgukg',
#  'total_received': 413500100000,
#  'total_sent': 413500000000,
#  'balance': 100000,
#  'unconfirmed_balance': 0,
#  'final_balance': 100000,
#  'n_tx': 3,
#  'unconfirmed_n_tx': 0,
#  'final_n_tx': 3,
#  'txs': [{'block_hash': '0000000000000000000270a555c9830ed0c068405a7f6279bd2523d77c7e0843',
#    'block_height': 885222,
#    'block_index': 1428,
#    'hash': '7ebad1a33d6df6361e09ae50b95e445f1e10407bb5563cd25c61dc389ab46afb',
#    'addresses': ['31rwnzGTFivTRaz6YvqRzxY39XMTzcGuV4',
#     'bc1q8yz92kk0y0a7hct8zsukg0gw50k7nyy47mueg8',
#     'bc1qvzn8l5rm70et6kc5r9xsxn9xwj80ycc4clgukg'],
#    'total': 413499999151,
#    'fees': 849,
#    'size': 224,
#    'vsize': 142,
#    'preference': 'low',
#    'relayed_by': '88.15.93.53:8333',
#    'confirmed': '2025-02-25T08:34:11Z',
#    'received': '2025-02-25T08:07:25.105Z',
#    'ver': 2,
#    'double_spend': False,
#    'vin_sz': 1,
#    'vout_sz': 2,
#    'opt_in_rbf': True,
# ...

# %%
res["txs"][0].keys()
# Out:
# dict_keys(['block_hash', 'block_height', 'block_index', 'hash', 'addresses', 'total', 'fees', 'size', 'vsize', 'preference', 'relayed_by', 'confirmed', 'received', 'ver', 'double_spend', 'vin_sz', 'vout_sz', 'opt_in_rbf', 'confirmations', 'confidence', 'inputs', 'outputs'])

# %%
res["txs"][0]["inputs"]
# Out:
# [{'prev_hash': 'c671221d536cb6cabef3e1485c39bcd1b01ff58ec545b5d132171b4cc6f63e00',
#   'output_index': 0,
#   'output_value': 413500000000,
#   'sequence': 0,
#   'addresses': ['bc1qvzn8l5rm70et6kc5r9xsxn9xwj80ycc4clgukg'],
#   'script_type': 'pay-to-witness-pubkey-hash',
#   'age': 883682,
#   'witness': ['3045022100aeaf2e4542e0d7f5f33f675938ef7d3afd9a60eabe21526337d86d618b4f8ccb022057bf81400e649498ce4f4f8d32bc7a755113bccbfc0c9f277a1c731b2689abf801',
#    '02257fc3999864e41012c24c1fbb89531f88a1c2a7d0bd5dd101b75f3758e24db9']}]

# %%
res["txs"][0]["outputs"]
# Out:
# [{'value': 9000000000,
#   'script': 'a91401e0b63b5b3641c0e65d307c1b938bcd5059c22587',
#   'spent_by': 'd11fefade33cc645157eb70f1af6e27505e7d8a6784cb90ffb6b408bb0a5a4c0',
#   'addresses': ['31rwnzGTFivTRaz6YvqRzxY39XMTzcGuV4'],
#   'script_type': 'pay-to-script-hash'},
#  {'value': 404499999151,
#   'script': '00143904555acf23fbebe1671439643d0ea3ede99095',
#   'addresses': ['bc1q8yz92kk0y0a7hct8zsukg0gw50k7nyy47mueg8'],
#   'script_type': 'pay-to-witness-pubkey-hash'}]
